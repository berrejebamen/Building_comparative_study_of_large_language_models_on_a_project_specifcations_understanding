# %% [markdown]
# # Preparing  metrics

# %%
#model_evaluation
import nltk
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.meteor_score import single_meteor_score
from nltk.translate.meteor_score import single_meteor_score
from nltk.translate.bleu_score import sentence_bleu ,SmoothingFunction
from rouge_score import rouge_scorer


def calculate_bleu_score(reference, hypothesis):
    # Tokenize the reference and hypothesis translations
    reference_tokens = nltk.word_tokenize(reference.lower())
    hypothesis_tokens = nltk.word_tokenize(hypothesis.lower())

    # Calculate BLEU score using NLTK's corpus BLEU implementation
    # We use weights=(1, 0, 0, 0) for unigram precision (BLEU-1)
    bleu_score = nltk.translate.bleu_score.sentence_bleu([reference_tokens], hypothesis_tokens, weights=(1, 0, 0, 0))
    
    return bleu_score






def compute_f1(predicted_answer, true_answer):
    predicted_tokens = set(predicted_answer.lower().split())
    true_tokens = set(true_answer.lower().split())
    common_tokens = predicted_tokens.intersection(true_tokens)
    precision = len(common_tokens) / (len(predicted_tokens) + 1e-8)
    recall = len(common_tokens) / (len(true_tokens) + 1e-8)
    f1 = 2 * (precision * recall) / (precision + recall + 1e-8)
    return f1



def calculate_rouge2_score(reference, candidate):
    scorer = rouge_scorer.RougeScorer(['rouge2'], use_stemmer=True)
    scores = scorer.score(reference, candidate)
    return scores['rouge2'].fmeasure


def load_existing_results(file_path):
    try:
        existing_df = pd.read_csv(file_path)
        return existing_df
    except FileNotFoundError:
        return pd.DataFrame(columns=["Question", "True Answer", "Predicted Answer", "BLEU Score", "ROUGE-2 Score"])

def save_dataframe_to_csv(dataframe, file_path):
    dataframe.to_csv(file_path, index=False)

# %% [markdown]
# # T5 BASED BOT

# %%
from transformers import pipeline
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

result_file_path = "output3.csv" 
existing_results_df = load_existing_results(result_file_path)

# Create the text-to-text pipeline for question answering
t5_qa = pipeline(task="text2text-generation", model="t5-large", tokenizer="t5-large")

# Read the content of "data.txt" and store it as the context
with open('data.txt', 'r', encoding='utf-8') as file:
    context =file.read()

while True:
    # User inputs the question
    question = input("Enter your question (type 'exit' to end): ")
 
    if question.lower() == 'exit':
        break 
        
   
    
    true_answer = input("Enter the true answer or type 'skip': ")
    
    if true_answer.lower() == "skip":
        # Generate the answer using the T5 model
        answer = t5_qa(f"question: {question} context: {context}")[0]['generated_text']
        print("Answer:", answer)
    else:
        
        
        # Get predicted answer and calculate scores
        predicted_answer = t5_qa(f"question: {question} context: {context}")[0]['generated_text']
      
        bleu_score = calculate_bleu_score(predicted_answer.capitalize(), true_answer.capitalize())
        rouge_score = calculate_rouge2_score(predicted_answer.capitalize(), true_answer.capitalize())
        new_data = {
                "Question": question.capitalize(),
                "Predicted Answer": predicted_answer.capitalize(),
                "True Answer": true_answer.capitalize(),
                "BLEU Score": bleu_score,
                "ROUGE-2 Score": rouge_score
            }
            
        existing_results_df = pd.concat([existing_results_df, pd.DataFrame([new_data])], ignore_index=True)
        save_dataframe_to_csv(existing_results_df, result_file_path)
            
        # Print results
        print("Predicted Answer:", predicted_answer)
        print("True Answer:", true_answer)
        print("BLEU Score:", bleu_score)
        print("ROUGE Score:", rouge_score)
        print("Results updated")
# Out:
# Enter your question (type 'exit' to end): what is the purpose of the Airline's referntial data
# Enter the true answer or type 'skip': Airline’s Referential Data have the purpose to represent the ecosystem (payment and other) of the Airline in Adad, allowing it to better use adad
# Predicted Answer: represent the ecosystem (payment and other) of the Airline in Adad, allowing it
# True Answer: Airline’s Referential Data have the purpose to represent the ecosystem (payment and other) of the Airline in Adad, allowing it to better use adad
# BLEU Score: 0.5517241379310345
# ROUGE Score: 0.6666666666666666
# Results updated
# Enter your question (type 'exit' to end): exit

# %% [markdown]
# # T5 FINAL RESULT

# %%
df=pd.read_csv("output3.csv") 
df.head(100)
# Out:
#                                              Question  \
# 0                                         What is etl
# 1                                         What is sla
# 2                            What does etl stand for
# 3                             What does sla stand for
# 4            A sla is a contract between who and who
# 5       What is the type of testing preferred at adad
# 6     What is the role of the etl configuration panel
# 7                                   What is load test
# 8                    Give me example of the file name
# 9           What format should the file name respect
# 10  How the adad gl file monitoring dashboard help...
# 11                               What is scaling plan
# 12          What is the overarching goal of load test
# 13          What is unit test in a clean architecture
# 14                       Example of naming convention
# 15                   Who is the provider of hot files
# 16                            What does bsp stand for
# 17   What is the purpose of the reconciliation module
# 18       What is the purpose of matching rules module
# 19        When the settlement is considered "settled"
# 20    When a settlement falls under "amount mismatch"
# 21                 When do the status "pending" apply
# 22  What happened when when the capture status of ...
# 23                            What does soc stand for
# 24  What is the purpose of airline’s referential data
# 25  What is the purpose of the airline's referntia...
# 26  What is the purpose of the airline's referntia...
#
#                                           True Answer  \
# 0    a data integration process that combines data...
# 1   Is a contract between a service provider and i...
# 2                          Extract , transform , load
# 3                             Service-level agreement
# 4                A service provider and its customers
# 5              Black box testing (behavioral testing)
# 6   The aim of the etl configuration panel is to p...
# 7   Load test is the objective is to ensure that l...
# 8   9429515695_epa_amex_20150818_0453389821883824_...
# 9    Ax_merchant_number_epa_amex_$utc_date$_utc_time
# 10  It allows to download gl files and detailed jo...
# 11  A scaling plan is a set of rules and costs ass...
# 12  The overarching goal is to achieve a comprehen...
# 13  In clean architecture, a unit test is a type o...
# 14  Salesreport_{airlinecode}{salesreportid}{recep...
# 15                      Billing settlement plan(bsp)
# 16                            Billing settlement plan
# 17  The purpose of the reconciliation module is to...
# 18  The matching rules module enables the user to ...
# 19  When it has been successfully matched to one o...
# 20   if it has been associated with a sale but the...
# 21       When no settlement has been linked to a sale
# 22     The "n/a" (not applicable) status is assigned
# 23                                 Summary of charge
# 24  Airline’s referential data have the purpose to...
# 25  Airline’s referential data have the purpose to...
# 26  Airline’s referential data have the purpose to...
#
#                                      Predicted Answer  BLEU Score  \
# 0   Extract, transform, and load, is a data integr...    0.250000
# 1   Service-level agreement (sla) is a contract be...    0.300000
# 2                        Extract, transform, and load    0.818731
# 3   Service-level agreement (sla) is a contract be...    0.002479
# 4                A service provider and its customers    1.000000
# 5              Black box testing (behavioral testing)    1.000000
# 6   The aim of the etl configuration panel is to p...    0.515152
# 7   Load test is the objective is to ensure that l...    0.481481
# 8                Ax_merchant_number_epa_amex_20150818    0.000000
# 9                    Ax_merchant_number_epa_amex_$utc    0.400000
# 10  It allows to download gl files and detailed jo...    0.789474
# 11  A scaling plan is a set of rules and costs ass...    0.319149
# 12  The overarching goal is to achieve a comprehen...    0.761905
# 13  A unit test is a type of automated test that i...    0.615385
# 14  Salesreport_airlinecodesalesreportidreceptiondate    0.000000
# 15  Billing settlement plan ( bsp) is the provider...    0.367879
# 16  Billing settlement plan( bsp) is the provider ...    0.049787
# 17  The purpose of the reconciliation module is to...    0.586207
# 18  Matching rules module enables the user to chan...    0.888889
# 19  When it has been successfully matched to one o...    0.642857
# 20  If it has been associated with a sale but the ...    0.695652
# 21       When no settlement has been linked to a sale    1.000000
# 22                           "n/a" status is assigned    0.545455
# 23                                  Summary of charge    1.000000
# 24  Adad gl file monitoring dashboard helps airlin...    0.034483
# 25  Adad gl file monitoring dashboard helps airlin...    0.034483
# 26  Represent the ecosystem (payment and other) of...    0.551724
#
#     ROUGE-2 Score
# 0        0.256410
# 1        0.400000
# 2        0.400000
# 3        0.285714
# 4        1.000000
# 5        1.000000
# 6        0.744186
# 7        0.631579
# 8        0.307692
# 9        0.769231
# 10       0.903226
# 11       0.491228
# 12       0.882353
# 13       0.810811
# 14       0.000000
# 15       0.500000
# 16       0.363636
# 17       0.780488
# 18       0.967742
# 19       0.761905
# 20       0.810811
# 21       1.000000
# 22       0.545455
# 23       1.000000
# 24       0.000000
# 25       0.000000
# 26       0.666667

# %% [markdown]
# # Randomly picking 10 rows from the output

# %%
import random
df = pd.read_csv('output3.csv')

# Randomly select five rows
num_samples = 10
random_indices = random.sample(range(len(df)), num_samples)
random_rows = df.iloc[random_indices]

random_rows.head(10)
# Out:
#                                              Question  \
# 21                 When do the status "pending" apply
# 8                    Give me example of the file name
# 13          What is unit test in a clean architecture
# 19        When the settlement is considered "settled"
# 2                            What does etl stand for
# 25  What is the purpose of the airline's referntia...
# 18       What is the purpose of matching rules module
# 9           What format should the file name respect
# 6     What is the role of the etl configuration panel
# 11                               What is scaling plan
#
#                                           True Answer  \
# 21       When no settlement has been linked to a sale
# 8   9429515695_epa_amex_20150818_0453389821883824_...
# 13  In clean architecture, a unit test is a type o...
# 19  When it has been successfully matched to one o...
# 2                          Extract , transform , load
# 25  Airline’s referential data have the purpose to...
# 18  The matching rules module enables the user to ...
# 9    Ax_merchant_number_epa_amex_$utc_date$_utc_time
# 6   The aim of the etl configuration panel is to p...
# 11  A scaling plan is a set of rules and costs ass...
#
#                                      Predicted Answer  BLEU Score  \
# 21       When no settlement has been linked to a sale    1.000000
# 8                Ax_merchant_number_epa_amex_20150818    0.000000
# 13  A unit test is a type of automated test that i...    0.615385
# 19  When it has been successfully matched to one o...    0.642857
# 2                        Extract, transform, and load    0.818731
# 25  Adad gl file monitoring dashboard helps airlin...    0.034483
# 18  Matching rules module enables the user to chan...    0.888889
# 9                    Ax_merchant_number_epa_amex_$utc    0.400000
# 6   The aim of the etl configuration panel is to p...    0.515152
# 11  A scaling plan is a set of rules and costs ass...    0.319149
#
#     ROUGE-2 Score
# 21       1.000000
# 8        0.307692
# 13       0.810811
# 19       0.761905
# 2        0.400000
# 25       0.000000
# 18       0.967742
# 9        0.769231
# 6        0.744186
# 11       0.491228
